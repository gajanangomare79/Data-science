# %% [markdown]
# Question1

# %%
#Question1
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from collections import Counter
from sklearn.metrics import accuracy_score

# %%
Naive_dataset=pd.read_csv(r"C:\Users\ggomare\Downloads\diabetes-2.csv")

# %%
Naive_dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
Naive_model=GaussianNB()

# %%
X_train=Naive_dataset.drop('Outcome',axis=1)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
Y_test=Naive_dataset['Outcome']

# %%
Y_test
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
Xtrain, Xtest, ytrain, ytest=train_test_split(X_train,Y_test,test_size=0.3, random_state=0)

# %%
Naivemodel1=Naive_model.fit(Xtrain,ytrain)

# %%
output1=Naivemodel1.predict(Xtest)

# %%
Counter(output1)
# Out:
# Counter({1: 57, 0: 174})

# %%
accuracy_score(output1,ytest)
# Out:
# 0.7619047619047619

# %%
output2=Naivemodel1.predict(Xtrain)

# %%
accuracy_score(output2,ytrain)
# Out:
# 0.7672253258845437

# %%
confu=confusion_matrix(output1, ytest)

# %%
confu
# Out:
# array([[138,  36],
#        [ 19,  38]], dtype=int64)

# %%
print(classification_report(output1, ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       174
#            1       0.51      0.67      0.58        57
#
#     accuracy                           0.76       231
#    macro avg       0.70      0.73      0.71       231
# weighted avg       0.79      0.76      0.77       231

# %% [markdown]
# # Question2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from matplotlib.colors import ListedColormap
from sklearn.inspection import DecisionBoundaryDisplay

# %%
from sklearn.preprocessing import StandardScaler 
 
scaler = StandardScaler() 
# Fit only on X_train 
scaler.fit(Xtrain) 
 
# Scale both X_train and X_test 
Xtrain = scaler.transform(Xtrain) 
Xtest = scaler.transform(Xtest)

# %%
KNN_model=KNeighborsClassifier(n_neighbors=5)

# %%
model_fit=KNN_model.fit(Xtrain,ytrain)

# %%
output3=model_fit.predict(Xtest)

# %%
accuracy_score(output3,ytest)
# Out:
# 0.7705627705627706

# %%
output4=model_fit.predict(Xtrain)

# %%
accuracy_score(output4,ytrain)
# Out:
# 0.7951582867783985

# %%
confu1=confusion_matrix(output3, ytest)

# %%
confu1
# Out:
# array([[134,  30],
#        [ 23,  44]], dtype=int64)

# %%
print(classification_report(output3, ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83       164
#            1       0.59      0.66      0.62        67
#
#     accuracy                           0.77       231
#    macro avg       0.72      0.74      0.73       231
# weighted avg       0.78      0.77      0.77       231

# %%
BloodP=Naive_dataset['BloodPressure'] 
BMI=Naive_dataset['BMI'] 
y=Naive_dataset['Outcome'] 
plt.scatter(BloodP, BMI, c=y)   # color in terms of label of PL and PW 
plt.xlabel('Blood Pressure') 
plt.ylabel('BMI') 
plt.title('Scatter Plot');

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
from sklearn.inspection import DecisionBoundaryDisplay

# %%
Semi_para=pd.DataFrame(data=Naive_dataset, columns=["BloodPressure","BMI"])

# %%
X=Semi_para
y=Naive_dataset['Outcome']

# %%
n_neighbors = 5
cmap_light = ListedColormap(["orange", "cyan", "cornflowerblue"])
cmap_bold = ["darkorange", "c", "darkblue"]


for weights in ["uniform", "distance"]:
    # we create an instance of Neighbours Classifier and fit the data.
    model = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    model.fit(X, y)

    _, ax= plt.subplots()
    DecisionBoundaryDisplay.from_estimator(model,X,cmap=cmap_light,ax=ax,response_method="predict",plot_method="pcolormesh",
        xlabel=X.columns[0],
        ylabel=X.columns[1],
        shading="auto")

 # Plot also the training points'

    sns.scatterplot(
        x=X.iloc[:,0],
        y=X.iloc[:,1],
        hue=y,
        palette=cmap_bold,
        alpha=1.0,
        edgecolor="black",
       )
    
    plt.title(
        "3-Class classification (k = %i, weights = '%s')" % (n_neighbors, weights));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 6>()
#      12    DecisionBoundaryDisplay.from_estimator(model,X,cmap=cmap_light,ax=ax,response_method="predict",plot_method="pcolormesh",
#      13        xlabel=X.columns[0],
#      14        ylabel=X.columns[1],
#      15        shading="auto")
#      17 # Plot also the training points'
# ---> 19    sns.scatterplot(
#      20        x=X.iloc[:,0],
#      21        y=X.iloc[:,1],
#      22        hue=y,
#      23        palette=cmap_bold,
#      24        alpha=1.0,
#      25        edgecolor="black",
#      26       )
#      28    plt.title(
#      29        "3-Class classification (k = %i, weights = '%s')" % (n_neighbors, weights))
#
# File ~\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
# ...

# %% [markdown]
# # Question 3

# %%
HousePrice=pd.read_csv(r"C:\Users\ggomare\Downloads\housePrice-2.csv")

# %%
HousePrice
# Out:
#       Area  Room  Parking  Warehouse  Elevator  Price (USD)
# 0       63     1        1          1         1        61667
# 1       60     1        1          1         1        61667
# 2       79     2        1          1         1        18333
# 3       95     2        1          1         1        30083
# 4      123     2        1          1         1       233333
# ...    ...   ...      ...        ...       ...          ...
# 3468    86     2        1          1         1       116667
# 3469    83     2        1          1         1       226667
# 3470    75     2        0          0         0        12167
# 3471   105     2        1          1         1       186667
# 3472    82     2        0          1         1        12000
#
# [3473 rows x 6 columns]

# %%
X1_train=HousePrice.drop("Price (USD)",axis=1)

# %%
X1_train.shape
# Out:
# (3473, 5)

# %%
Y1_test=HousePrice["Price (USD)"]

# %%
Y1_test
# Out:
# 0        61667
# 1        61667
# 2        18333
# 3        30083
# 4       233333
#          ...
# 3468    116667
# 3469    226667
# 3470     12167
# 3471    186667
# 3472     12000
# Name: Price (USD), Length: 3473, dtype: int64

# %%
X1train, X1test, y1train, y1test=train_test_split(X1_train,Y1_test,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler 
 
scaler = StandardScaler() 
# Fit only on X_train 
scaler.fit(X1train) 
 
# Scale both X_train and X_test 
X1train = scaler.transform(X1train) 
X1test = scaler.transform(X1test)

# %%
X1train
# Out:
# array([[-0.96273715, -1.41699687,  0.42235175,  0.30508284, -1.92645797],
#        [-0.22020154, -0.10221848,  0.42235175,  0.30508284,  0.51908737],
#        [-0.35123724, -0.10221848,  0.42235175,  0.30508284,  0.51908737],
#        ...,
#        [ 0.60969121, -0.10221848,  0.42235175, -3.27779825,  0.51908737],
#        [-0.90449907, -1.41699687,  0.42235175,  0.30508284, -1.92645797],
#        [-0.67154672, -1.41699687,  0.42235175,  0.30508284,  0.51908737]])

# %%
from sklearn.neighbors import KNeighborsRegressor    
 
regressor = KNeighborsRegressor(n_neighbors=5) 
 
regremodel=regressor.fit(X1train, y1train)

# %%
output5=regremodel.predict(X1test)

# %%
output5
# Out:
# array([ 80866.6,  93866.6, 398400. , ..., 247573.4, 189666.6, 187200. ])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error    
 
mae = mean_absolute_error(y1test, output5) 
mse = mean_squared_error(y1test, output5)
 
print('mae is: ', mae) 
print('mse is: ', mse)
# Out:
# mae is:  78776.7971209213
# mse is:  28098590632.377705

# %%
R2= regressor.score(X1test, y1test) 
 
print('R2 is:', R2)
# Out:
# R2 is: 0.5838105328710905

# %%
error=[]
for i in range(1, 30):   
    knn = KNeighborsRegressor(n_neighbors=i) 
    knn.fit(X1train, y1train) 
    pred_i = knn.predict(X1test) 
    mae = mean_absolute_error(y1test, pred_i) 
    error.append(mae)

# %%
error
# Out:
# [94595.73800383878,
#  88963.65834932821,
#  84670.93506078055,
#  81652.0067178503,
#  78776.7971209213,
#  76892.87380038388,
#  76114.51343570057,
#  76093.12152111324,
#  76607.21102580508,
#  76139.0068138196,
#  76792.72954109231,
#  76407.86284388996,
#  75870.05300457698,
#  75342.20359199341,
#  75185.80614203455,
#  74728.22504798464,
#  74711.6515185729,
#  75404.43841970571,
#  75072.44231740579,
#  75250.7797024952,
#  75041.6316607257,
#  74994.6720031408,
#  75086.73917216057,
#  75272.67502399233,
#  74998.20936660269,
#  74934.61711944485,
#  74856.69474656999,
#  74906.49156841238,
#  74875.69998014429]

# %%
import matplotlib.pyplot as plt  
 
plt.figure(figsize=(12, 6))    
 
plt.plot(range(1, 30), error, color='red', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=10) 
          
plt.title('K Value MAE') 
plt.xlabel('K Value') 
plt.ylabel('Mean Absolute Error (MAE)');

# %%
error2 = [] 
 
# Calculating MAE error for K values between 1 and 39
for i in range(1, 30): 
    knn = KNeighborsRegressor(n_neighbors=i) 
    knn.fit(X1train, y1train) 
    pred_i = knn.predict(X1test) 
    mse = mean_squared_error(y1test, pred_i) 
    error2.append(mse)

# %%
import matplotlib.pyplot as plt  
 
plt.figure(figsize=(12, 6)) 
 
plt.plot(range(1, 30), error2, color='green', linestyle='dashed', marker='o',markerfacecolor='red', markersize=10) 
          
plt.title('K Value MSE') 
plt.xlabel('K Value') 
plt.ylabel('Mean Squared Error (MSE)');

# %% [markdown]
# # Question 4

# %%
plt.figure(figsize=(16, 6)) 
 
heatmap = sns.heatmap(Naive_dataset.corr(), vmin=-1, vmax=1, annot=True, cmap='gist_rainbow_r') 
 
heatmap.set_title('Correlation Heatmap');

# %%
sns.lmplot(data=Naive_dataset, x='Glucose', y='BloodPressure')

# %%
sns.lmplot(data=Naive_dataset, x='Age', y='BloodPressure')

# %%
sns.pairplot(data=Naive_dataset, hue="Outcome", palette='gist_rainbow_r')

# %%
mu, sigma = 100, 15 
x = mu + sigma * np.random.randn(10000) 
 
# the histogram of the data 
plt.hist(x, 12000, density=True, facecolor='r', alpha=0.75) # density=true  calculates the probability density function fo
 
 
plt.xlabel('IQ') 
plt.ylabel('Probability') 
plt.title('Histogram of IQ') 
plt.text(60, .025,'$\mu=100,\ \sigma=15$') 
plt.xlim(40, 160) 
plt.ylim(0, 0.03) 
plt.grid(False) 
plt.show()

# %%
from scipy.stats import poisson 
 
data_poisson = poisson.rvs(mu=3, size=8000) 
ax = sns.distplot(data_poisson,kde=True,color='red',hist_kws={"linewidth": 15,'alpha':1}) 
 
ax.set(xlabel='Poisson', ylabel='Frequency')
# Out:
# C:\Users\ggomare\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Poisson'), Text(0, 0.5, 'Frequency')]

# %%
Semi_para1=pd.DataFrame(data=Naive_dataset, columns=["Glucose","BloodPressure"])
Semi_para1
# Out:
#      Glucose  BloodPressure
# 0        148             72
# 1         85             66
# 2        183             64
# 3         89             66
# 4        137             40
# ..       ...            ...
# 763      101             76
# 764      122             70
# 765      121             72
# 766      126             60
# 767       93             70
#
# [768 rows x 2 columns]

# %%
sns.violinplot(data=Semi_para1, orient='v', palette='Set2')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=Semi_para1, orient='h', palette='Set2', notch='True')       # notch=True   # edges on median 
sns.stripplot(data=Semi_para1, orient='h', palette='Set2');

# %%
sns.stripplot(data=Semi_para1, orient='v', palette='Set2')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=Semi_para1, orient='h', palette='Oranges_r');
