# %% [markdown]
# # Question 1

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r"C:\Users\ggomare\Downloads\archive (3)\CC GENERAL.csv")

# %%
dataset
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
dataset.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
dataset.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
dataset["MINIMUM_PAYMENTS"].fillna(dataset["MINIMUM_PAYMENTS"].mean(),inplace=True)
dataset["CREDIT_LIMIT"].fillna(dataset["CREDIT_LIMIT"].mean(),inplace=True)

# %%
dataset1=dataset.drop(columns=["CUST_ID"])

# %%
dataset1.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
from sklearn.cluster import KMeans

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # Hyperparameter tunning

# %%
Question1 = []
parameter1=['k-means++', 'random']
parameter2=[2,4,6,8,10,12]
k_rng = range(1,20)
for k in k_rng:
    for P in parameter1:
        for Q in parameter2:
            means= KMeans(n_clusters=k,init=P,n_init=Q)
            means.fit(dataset1)
            Question1.append(means.inertia_)

# %%
sse = []
k_rng = range(1,20)
for k in k_rng:
    means = KMeans(n_clusters=k)
    means.fit(dataset1)
    sse.append(means.inertia_)

# %%
from matplotlib import pyplot as plt
plt.plot(k_rng,sse)

# %%
means=KMeans(n_clusters=3)
predicted=means.fit_predict(dataset1)
predicted
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
from collections import Counter
Counter(predicted)
# Out:
# Counter({0: 6517, 1: 2299, 2: 134})

# %%
dataset1["predicted"]=predicted

# %%
dataset1
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
label_0=dataset1[dataset1["predicted"]==0]
label_1=dataset1[dataset1["predicted"]==1]
label_2=dataset1[dataset1["predicted"]==2]

# %%
label_0
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 8     1014.926473           1.000000     861.49            661.49
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
labels=[0,1,2]
PURCHASESFREQUENCY=[]
PURCHASESFREQUENCY.append(label_0["PURCHASES_FREQUENCY"].mean())
PURCHASESFREQUENCY.append(label_1["PURCHASES_FREQUENCY"].mean())
PURCHASESFREQUENCY.append(label_2["PURCHASES_FREQUENCY"].mean())
plt.bar(labels,PURCHASESFREQUENCY,width=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
labels=[0,1,2]
BALANCE=[]
BALANCE.append(label_0["BALANCE"].mean())
BALANCE.append(label_1["BALANCE"].mean())
BALANCE.append(label_2["BALANCE"].mean())
plt.bar(labels,BALANCE,width=0.5)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Question 2

# %%
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
dataset2=pd.read_csv(r"C:\Users\ggomare\Downloads\SouthGermanCreditquestion2.csv")

# %%
dataset2
# Out:
#      laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0           1        18      4     2   1049         1        2     4       2
# 1           1         9      4     0   2799         1        3     2       3
# 2           2        12      2     9    841         2        4     2       2
# 3           1        12      4     0   2122         1        3     3       3
# 4           1        12      4     0   2171         1        3     4       3
# ..        ...       ...    ...   ...    ...       ...      ...   ...     ...
# 995         1        24      2     3   1987         1        3     2       3
# 996         1        24      2     0   2303         1        5     4       3
# 997         4        21      4     0  12680         5        5     4       3
# 998         2        12      2     3   6468         5        1     2       3
# 999         1        30      2     2   6350         5        5     4       3
#
# ...

# %%
dataset21=dataset2.drop(columns=["kredit"])

# %%
dataset2["kredit"].value_counts()
# Out:
# 1    700
# 0    300
# Name: kredit, dtype: int64

# %%
dataset21.isnull().sum()
# Out:
# laufkont    0
# laufzeit    0
# moral       0
# verw        0
# hoehe       0
# sparkont    0
# beszeit     0
# rate        0
# famges      0
# buerge      0
# wohnzeit    0
# verm        0
# alter       0
# weitkred    0
# wohn        0
# bishkred    0
# beruf       0
# pers        0
# telef       0
# gastarb     0
# dtype: int64

# %% [markdown]
# # Hyperparameter Tunning

# %%
import warnings
warnings.filterwarnings("ignore")
Question2 = []
parameter1=['k-means++', 'random']
parameter2=[2,4,6,8,10,12]
k_rng = range(1,20)
for k in k_rng:
    for l in parameter1:
        for m in parameter2:
            cluster_model= KMeans(n_clusters=k,init=l,n_init=m)
            cluster_model.fit(dataset21)
            Question2.append(cluster_model.inertia_)

# %%
question21 = []
k_rng = range(1,20)
for k in k_rng:
    cluster_model = KMeans(n_clusters=k)
    cluster_model.fit(dataset21)
    question21.append(cluster_model.inertia_)

# %%
plt.plot(k_rng,question21)

# %%
cluster_model= KMeans(n_clusters=4)
prediction=cluster_model.fit_predict(dataset21)

# %%
dataset2["clusters_label"]=prediction

# %%
dataset2
# Out:
#      laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0           1        18      4     2   1049         1        2     4       2
# 1           1         9      4     0   2799         1        3     2       3
# 2           2        12      2     9    841         2        4     2       2
# 3           1        12      4     0   2122         1        3     3       3
# 4           1        12      4     0   2171         1        3     4       3
# ..        ...       ...    ...   ...    ...       ...      ...   ...     ...
# 995         1        24      2     3   1987         1        3     2       3
# 996         1        24      2     0   2303         1        5     4       3
# 997         4        21      4     0  12680         5        5     4       3
# 998         2        12      2     3   6468         5        1     2       3
# 999         1        30      2     2   6350         5        5     4       3
#
# ...

# %%
cluster_0=dataset2[dataset2["clusters_label"]==0]
cluster_1=dataset2[dataset2["clusters_label"]==1]
cluster_2=dataset2[dataset2["clusters_label"]==2]
cluster_3=dataset2[dataset2["clusters_label"]==3]

# %%
cluster_0["kredit"].value_counts()
# Out:
# 1    396
# 0    148
# Name: kredit, dtype: int64

# %%
cluster_0["new_kredit"]=1

# %%
cluster_0["new_kredit"].value_counts()
# Out:
# 1    544
# Name: new_kredit, dtype: int64

# %%
cluster_1["kredit"].value_counts()
# Out:
# 1    83
# 0    47
# Name: kredit, dtype: int64

# %%
cluster_1["new_kredit"]=1

# %%
cluster_2["kredit"].value_counts()
# Out:
# 0    25
# 1    17
# Name: kredit, dtype: int64

# %%
cluster_2["new_kredit"]=0

# %%
cluster_3["kredit"].value_counts()
# Out:
# 1    204
# 0     80
# Name: kredit, dtype: int64

# %%
cluster_3["new_kredit"]=1

# %%
finalpred=list(cluster_0["new_kredit"])+list(cluster_1["new_kredit"])+list(cluster_2["new_kredit"])+list(cluster_3["new_kredit"])

# %%
prepred=list(cluster_0["kredit"])+list(cluster_1["kredit"])+list(cluster_2["kredit"])+list(cluster_3["kredit"])

# %%
from sklearn.metrics import classification_report
print(classification_report(finalpred,prepred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.08      0.60      0.15        42
#            1       0.98      0.71      0.82       958
#
#     accuracy                           0.71      1000
#    macro avg       0.53      0.65      0.49      1000
# weighted avg       0.94      0.71      0.80      1000

# %%
BAD_CREDICT=cluster_2

# %%
BAD_CREDICT
# Out:
#      laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 63          4        36      3     0  10875         1        5     2       3
# 179         4        48      3     3  12749         3        4     4       3
# 208         2        48      1     0  12169         5        1     4       3
# 218         1        47      2     0  10722         1        2     1       2
# 241         4        60      2     0  10366         1        5     2       3
# 355         4        36      4     1  10477         5        5     2       3
# 382         4        60      4     0  13756         5        5     2       3
# 426         2        39      3     6  11760         2        4     2       3
# 442         1        39      4     2  14179         5        4     4       3
# 521         4        36      2     2  10974         1        1     4       2
# 566         2        36      3     9   9857         2        4     1       3
# ...
