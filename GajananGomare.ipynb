# %%
import pandas as pd
import numpy as np
import seaborn as sn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

# %%
fraud_train=pd.read_csv(r"C:\Users\ggomare\Downloads\Insurance Fraud - TRAIN-3000.csv")

# %%
fraud_train
# Out:
#      MONTH  WEEKOFMONTH  DAYOFWEEK       MAKE ACCIDENTAREA DAYOFWEEKCLAIMED  \
# 0      Jul            3     Sunday      Honda        Rural        Wednesday
# 1      Nov            5     Monday      Mazda        Urban        Wednesday
# 2      Jan            1     Monday    Pontiac        Urban        Wednesday
# 3      Dec            1     Monday     Toyota        Rural          Tuesday
# 4      Dec            5  Wednesday    Pontiac        Urban        Wednesday
# ...    ...          ...        ...        ...          ...              ...
# 2994   Apr            2     Monday    Pontiac        Rural           Monday
# 2995   Nov            4   Thursday      Honda        Urban           Friday
# 2996   Dec            4     Sunday  Chevrolet        Urban        Wednesday
# 2997   Apr            1     Monday     Toyota        Urban          Tuesday
# 2998   Jun            4     Friday    Pontiac        Urban        Wednesday
#
# ...

# %%
columns_array=fraud_train.columns

# %%
fraud_train["YEAR"].unique()
# Out:
# array([1994, 1995, 1996], dtype=int64)

# %%
fraud_train.columns.shape
# Out:
# (32,)

# %%
final_column=columns_array.drop(["WEEKOFMONTH","WEEKOFMONTHCLAIMED","YEAR","AGE","REPNUMBER","DEDUCTIBLE","DRIVERRATING"])

# %%
final_column
# Out:
# Index(['MONTH', 'DAYOFWEEK', 'MAKE', 'ACCIDENTAREA', 'DAYOFWEEKCLAIMED',
#        'MONTHCLAIMED', 'SEX', 'MARITALSTATUS', 'FAULT', 'POLICYTYPE',
#        'VEHICLECATEGORY', 'VEHICLEPRICE', 'DAYS_POLICY_ACCIDENT',
#        'DAYS_POLICY_CLAIM', 'PASTNUMBEROFCLAIMS', 'AGEOFVEHICLE',
#        'AGEOFPOLICYHOLDER', 'POLICEREPORTFILED', 'WITNESSPRESENT', 'AGENTTYPE',
#        'NUMBEROFSUPPLIMENTS', 'ADDRESSCHANGE_CLAIM', 'NUMBEROFCARS',
#        'BASEPOLICY', 'FRAUDFOUND'],
#       dtype='object')

# %%
lb_encode=LabelEncoder()

# %%
for i in final_column:
    fraud_train[i+"1"]=lb_encode.fit_transform(fraud_train[i])

# %%
final_fraud_train=fraud_train.drop(columns=final_column,axis=1)

# %%
final_fraud_train
# Out:
#       WEEKOFMONTH  WEEKOFMONTHCLAIMED  AGE  REPNUMBER  DEDUCTIBLE  \
# 0               3                   4   21          4         400
# 1               5                   1   68          9         400
# 2               1                   1   50          8         400
# 3               1                   3   39          1         400
# 4               5                   1   43          1         400
# ...           ...                 ...  ...        ...         ...
# 2994            2                   2   45          1         400
# 2995            4                   4   35          9         400
# 2996            4                   1   69          7         400
# 2997            1                   1   33         10         400
# 2998            4                   1   30          8         400
#
#       DRIVERRATING  YEAR  MONTH1  DAYOFWEEK1  MAKE1  ...  AGEOFVEHICLE1  \
# 0                4  1994       5           3      5  ...              2
# ...

# %%
fraud_test=pd.read_csv(r"C:\Users\ggomare\Downloads\Insurance Fraud -TEST-12900.csv")

# %%
fraud_test
# Out:
#       MONTH  WEEKOFMONTH  DAYOFWEEK       MAKE ACCIDENTAREA DAYOFWEEKCLAIMED  \
# 0       Jul            3     Sunday      Honda        Rural        Wednesday
# 1       Nov            5     Monday      Mazda        Urban        Wednesday
# 2       Jan            1     Monday    Pontiac        Urban        Wednesday
# 3       Dec            1     Monday     Toyota        Rural          Tuesday
# 4       Dec            5  Wednesday    Pontiac        Urban        Wednesday
# ...     ...          ...        ...        ...          ...              ...
# 12913   Dec            1    Tuesday    Pontiac        Urban         Thursday
# 12914   Oct            2    Tuesday     Accura        Urban         Thursday
# 12915   Apr            4     Monday     Toyota        Urban        Wednesday
# 12916   Jun            2     Friday      Mazda        Urban           Friday
# 12917   Jun            2  Wednesday  Chevrolet        Urban        Wednesday
#
# ...

# %%
final1_column=fraud_test.columns.drop(["WEEKOFMONTH","WEEKOFMONTHCLAIMED","YEAR","AGE","REPNUMBER","DEDUCTIBLE","DRIVERRATING"])

# %%
final1_column.shape
# Out:
# (25,)

# %%
for i in final1_column:
    fraud_test[i+"1"]=lb_encode.fit_transform(fraud_test[i])

# %%
final_fraud_test=fraud_test.drop(columns=final1_column,axis=1)

# %%
final_fraud_test
# Out:
#        WEEKOFMONTH  WEEKOFMONTHCLAIMED  AGE  REPNUMBER  DEDUCTIBLE  \
# 0                3                   4   21          4         400
# 1                5                   1   68          9         400
# 2                1                   1   50          8         400
# 3                1                   3   39          1         400
# 4                5                   1   43          1         400
# ...            ...                 ...  ...        ...         ...
# 12913            1                   1   62          2         400
# 12914            2                   3   27         16         400
# 12915            4                   4   73         11         400
# 12916            2                   2   73         14         400
# 12917            2                   2   49          2         400
#
#        DRIVERRATING  YEAR  MONTH1  DAYOFWEEK1  MAKE1  ...  AGEOFVEHICLE1  \
# 0                 4  1994       5           3      6  ...              2
# ...

# %%
from sklearn import tree
from matplotlib import pyplot as ply
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
fraud_train_x=final_fraud_train.drop("FRAUDFOUND1",axis=1)

# %%
fraud_train_y=final_fraud_train["FRAUDFOUND1"]

# %%
fraud_train_x
# Out:
#       WEEKOFMONTH  WEEKOFMONTHCLAIMED  AGE  REPNUMBER  DEDUCTIBLE  \
# 0               3                   4   21          4         400
# 1               5                   1   68          9         400
# 2               1                   1   50          8         400
# 3               1                   3   39          1         400
# 4               5                   1   43          1         400
# ...           ...                 ...  ...        ...         ...
# 2994            2                   2   45          1         400
# 2995            4                   4   35          9         400
# 2996            4                   1   69          7         400
# 2997            1                   1   33         10         400
# 2998            4                   1   30          8         400
#
#       DRIVERRATING  YEAR  MONTH1  DAYOFWEEK1  MAKE1  ...  PASTNUMBEROFCLAIMS1  \
# 0                4  1994       5           3      5  ...                    3
# ...

# %%
fraud_train_y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2994    0
# 2995    0
# 2996    0
# 2997    0
# 2998    0
# Name: FRAUDFOUND1, Length: 2999, dtype: int32

# %%
fraud_test_x=final_fraud_test.drop("FRAUDFOUND1",axis=1)

# %%
fraud_test_y=final_fraud_test["FRAUDFOUND1"]

# %%
fraud_test_x.isnull().sum()
# Out:
# WEEKOFMONTH              0
# WEEKOFMONTHCLAIMED       0
# AGE                      0
# REPNUMBER                0
# DEDUCTIBLE               0
# DRIVERRATING             0
# YEAR                     0
# MONTH1                   0
# DAYOFWEEK1               0
# MAKE1                    0
# ACCIDENTAREA1            0
# DAYOFWEEKCLAIMED1        0
# MONTHCLAIMED1            0
# SEX1                     0
# MARITALSTATUS1           0
# FAULT1                   0
# POLICYTYPE1              0
# VEHICLECATEGORY1         0
# VEHICLEPRICE1            0
# DAYS_POLICY_ACCIDENT1    0
# DAYS_POLICY_CLAIM1       0
# PASTNUMBEROFCLAIMS1      0
# AGEOFVEHICLE1            0
# AGEOFPOLICYHOLDER1       0
# POLICEREPORTFILED1       0
# WITNESSPRESENT1          0
# AGENTTYPE1               0
# NUMBEROFSUPPLIMENTS1     0
# ADDRESSCHANGE_CLAIM1     0
# NUMBEROFCARS1            0
# BASEPOLICY1              0
# dtype: int64

# %% [markdown]
# Cross_validation for fraud data

# %%
accuracy_Decision=cross_val_score(tree.DecisionTreeClassifier(),fraud_train_x,fraud_train_y,cv=6)

# %%
accuracy_Decision
# Out:
# array([0.836     , 0.804     , 0.836     , 0.818     , 0.816     ,
#        0.80360721])

# %%
Accuracy_random=cross_val_score(RandomForestClassifier(),fraud_train_x,fraud_train_y,cv=6)

# %%
Accuracy_random
# Out:
# array([0.892     , 0.88      , 0.89      , 0.866     , 0.866     ,
#        0.88577154])

# %%
Avg_accuracy_decison=sum(accuracy_Decision)/len(accuracy_Decision)

# %%
avg_accuracy_random=sum(Accuracy_random)/len(Accuracy_random)

# %%
(Avg_accuracy_decison,avg_accuracy_random)
# Out:
# (0.8189345357381429, 0.8799619238476954)

# %%
model1=tree.DecisionTreeClassifier()

# %%
Input1=model1.fit(fraud_train_x,fraud_train_y)

# %%
result1=Input1.predict(fraud_test_x)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
accuracy_score(result1,fraud_test_y)
# Out:
# 0.8808639108221087

# %%
precision_score(result1,fraud_test_y)
# Out:
# 0.8514056224899599

# %%
f1_score(result1,fraud_test_y)
# Out:
# 0.35525764558022627

# %% [markdown]
# # Fraud Detection using DecisionTreeClassifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# DecisionTreeClassifier USING HyperParameterTunning

# %%
#GridsearchCV
Model=GridSearchCV(DecisionTreeClassifier(),{
    "criterion":["gini", "entropy", "log_loss"],
    "splitter":["best", "random"], 
    "max_depth":[1,2,5,10,15],
     "min_samples_leaf":[1,2,4,8,10]
    },cv=6,return_train_score=False)
Model.fit(fraud_train_x,fraud_train_y)
# Out:
# GridSearchCV(cv=6, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4, 8, 10],
#                          'splitter': ['best', 'random']})

# %%
final_model
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.004930      0.001304         0.001775        0.000365
# 1         0.006500      0.002539         0.002858        0.000986
# 2         0.007426      0.001395         0.003967        0.002235
# 3         0.007159      0.001439         0.001893        0.001940
# 4         0.007620      0.002429         0.004571        0.003240
# ..             ...           ...              ...             ...
# 145       0.006287      0.002400         0.002665        0.002426
# 146       0.011598      0.000674         0.001600        0.000604
# 147       0.007255      0.000973         0.001707        0.000568
# 148       0.015573      0.002650         0.002744        0.000748
# 149       0.009431      0.001435         0.002537        0.000550
#
#     param_criterion param_max_depth param_min_samples_leaf param_splitter  \
# 0              gini               1                      1           best
# ...

# %%
final_model[["params","mean_test_score"]]# results with different parameters
# Out:
#                                                 params  mean_test_score
# 0    {'criterion': 'gini', 'max_depth': 1, 'min_sam...         0.842289
# 1    {'criterion': 'gini', 'max_depth': 1, 'min_sam...         0.866956
# 2    {'criterion': 'gini', 'max_depth': 1, 'min_sam...         0.842289
# 3    {'criterion': 'gini', 'max_depth': 1, 'min_sam...         0.866956
# 4    {'criterion': 'gini', 'max_depth': 1, 'min_sam...         0.842289
# ..                                                 ...              ...
# 145  {'criterion': 'log_loss', 'max_depth': 15, 'mi...         0.843277
# 146  {'criterion': 'log_loss', 'max_depth': 15, 'mi...         0.839607
# 147  {'criterion': 'log_loss', 'max_depth': 15, 'mi...         0.853951
# 148  {'criterion': 'log_loss', 'max_depth': 15, 'mi...         0.845621
# 149  {'criterion': 'log_loss', 'max_depth': 15, 'mi...         0.861278
#
# [150 rows x 2 columns]

# %%
Model.best_score_# best score after applying Hypertunning
# Out:
# 0.8909639278557115

# %%
report=classification_report(fraud_test_y,result1)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93     12420
#            1       0.22      0.85      0.36       498
#
#     accuracy                           0.88     12918
#    macro avg       0.61      0.87      0.64     12918
# weighted avg       0.96      0.88      0.91     12918

# %%
Model.fit(fraud_test_x,fraud_test_y)
# Out:
# GridSearchCV(cv=6, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4, 8, 10],
#                          'splitter': ['best', 'random']})

# %%
Model.best_score_
# Out:
# 0.9627651339216597

# %%
Model.best_params_
# Out:
# {'splitter': 'best',
#  'min_samples_leaf': 10,
#  'max_depth': 5,
#  'criterion': 'log_loss'}

# %%
get1=tree.DecisionTreeClassifier(splitter='best',min_samples_leaf= 10,max_depth= 5,criterion='log_loss')

# %%
get1.fit(fraud_train_x,fraud_train_y)
# Out:
# DecisionTreeClassifier(criterion='log_loss', max_depth=5, min_samples_leaf=10)

# %%
get1.score(fraud_test_x,fraud_test_y)
# Out:
# 0.8737420653351912

# %%
getpre=get1.predict(fraud_test_x)

# %%
print(classification_report(getpre,fraud_test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93     11335
#            1       0.45      0.14      0.22      1583
#
#     accuracy                           0.87     12918
#    macro avg       0.67      0.56      0.57     12918
# weighted avg       0.84      0.87      0.84     12918

# %%
#Random search 
from sklearn.model_selection import RandomizedSearchCV

# %%
Model=RandomizedSearchCV(DecisionTreeClassifier(),{
    "criterion":["gini", "entropy", "log_loss"],
    "splitter":["best", "random"], 
    "max_depth":[1,2,5,10,15],
     "min_samples_leaf":[1,2,4,8,10]
    },cv=6,return_train_score=False)
Model.fit(fraud_test_x,fraud_test_y)
# Out:
# RandomizedSearchCV(cv=6, estimator=DecisionTreeClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': [1, 2, 5, 10, 15],
#                                         'min_samples_leaf': [1, 2, 4, 8, 10],
#                                         'splitter': ['best', 'random']})

# %%
Model.best_score_
# Out:
# 0.9626103111936833

# %%
Model.best_params_
# Out:
# {'splitter': 'best',
#  'min_samples_leaf': 10,
#  'max_depth': 5,
#  'criterion': 'log_loss'}

# %%
get2=RandomForestClassifier(min_samples_leaf= 10, max_depth= 5,criterion='log_loss')

# %%
get2.fit(fraud_train_x,fraud_train_y)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=5, min_samples_leaf=10)

# %%
pre2=get2.predict(fraud_test_x)

# %%
get2.score(fraud_test_x,fraud_test_y)
# Out:
# 0.9550239975228364

# %%
print(classification_report(fraud_test_y,pre2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     12420
#            1       0.31      0.13      0.19       498
#
#     accuracy                           0.96     12918
#    macro avg       0.64      0.56      0.58     12918
# weighted avg       0.94      0.96      0.95     12918

# %% [markdown]
# # Fraud Detection using RandomForestClassification

# %%
rfc=RandomForestClassifier(random_state=42)

# %%
param_grid = { 

     'max_features': ['sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
Model1= GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)

# %%
Model1
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['sqrt', 'log2']})

# %%
Model1.fit(fraud_train_x,fraud_train_y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['sqrt', 'log2']})

# %%
final_random=pd.DataFrame(Model1.cv_results_)

# %%
final_random
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.457315      0.008531         0.041128        0.001402
# 1        0.369355      0.091159         0.029957        0.011204
# 2        0.330335      0.049916         0.026010        0.008997
# 3        0.339689      0.034432         0.025362        0.008374
# 4        0.413606      0.066101         0.032118        0.006937
# 5        0.391257      0.080938         0.031201        0.009984
# 6        0.460231      0.076520         0.036302        0.003456
# 7        0.335732      0.071905         0.024591        0.007666
# 8        0.379315      0.084401         0.027070        0.010228
# 9        0.318818      0.110036         0.021141        0.003516
# 10       0.251356      0.055890         0.018237        0.006704
# 11       0.392824      0.038831         0.034983        0.004408
# 12       0.348693      0.057880         0.029824        0.007742
# ...

# %%
final_random[["params","mean_test_score"]]
# Out:
#                                                params  mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 4, 'max_fea...         0.867623
# 1   {'criterion': 'gini', 'max_depth': 4, 'max_fea...         0.866956
# 2   {'criterion': 'gini', 'max_depth': 5, 'max_fea...         0.872958
# 3   {'criterion': 'gini', 'max_depth': 5, 'max_fea...         0.867289
# 4   {'criterion': 'gini', 'max_depth': 6, 'max_fea...         0.878959
# 5   {'criterion': 'gini', 'max_depth': 6, 'max_fea...         0.871290
# 6   {'criterion': 'gini', 'max_depth': 7, 'max_fea...         0.886294
# 7   {'criterion': 'gini', 'max_depth': 7, 'max_fea...         0.874291
# 8   {'criterion': 'gini', 'max_depth': 8, 'max_fea...         0.884627
# 9   {'criterion': 'gini', 'max_depth': 8, 'max_fea...         0.879294
# 10  {'criterion': 'entropy', 'max_depth': 4, 'max_...         0.867289
# 11  {'criterion': 'entropy', 'max_depth': 4, 'max_...         0.866956
# ...

# %%
Model1.best_score_
# Out:
# 0.8862938230383974

# %%
Model1.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt'}

# %%
Model1.fit(fraud_test_x,fraud_test_y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['sqrt', 'log2']})

# %%
Model1.best_score_
# Out:
# 0.9614491753055523

# %%
Model1.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt'}

# %%
gre3=RandomForestClassifier(criterion='gini', max_depth= 4, max_features= 'sqrt')

# %%
gre3.fit(fraud_train_x,fraud_train_y)
# Out:
# RandomForestClassifier(max_depth=4)

# %%
pre3=gre3.predict(fraud_test_x)

# %%
gre3.score(fraud_test_x,fraud_test_y)
# Out:
# 0.9614491407338597

# %%
print(classification_report(fraud_test_y,pre3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     12420
#            1       0.00      0.00      0.00       498
#
#     accuracy                           0.96     12918
#    macro avg       0.48      0.50      0.49     12918
# weighted avg       0.92      0.96      0.94     12918
# C:\Users\ggomare\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ggomare\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
Model1r= RandomizedSearchCV(estimator=rfc,param_distributions=param_grid, cv= 5)

# %%
Model1r.fit(fraud_test_x,fraud_test_y)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [4, 5, 6, 7, 8],
#                                         'max_features': ['sqrt', 'log2']})

# %%
Model1r.best_score_
# Out:
# 0.9614491753055523

# %%
Model1r.best_params_
# Out:
# {'max_features': 'sqrt', 'max_depth': 4, 'criterion': 'entropy'}

# %%
gre4=RandomForestClassifier(max_features='sqrt', max_depth= 4, criterion='entropy')

# %%
gre4.fit(fraud_train_x,fraud_train_y)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=4)

# %%
pre4=gre4.predict(fraud_test_x)

# %%
gre4.score(fraud_test_x,fraud_test_y)
# Out:
# 0.9616039634618362

# %%
print(classification_report(pre4,fraud_test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     12914
#            1       0.01      0.75      0.01         4
#
#     accuracy                           0.96     12918
#    macro avg       0.50      0.86      0.50     12918
# weighted avg       1.00      0.96      0.98     12918

# %% [markdown]
# # Target Marketing

# %%
target_train=pd.read_csv(r"C:\Users\ggomare\Downloads\Portugese Bank Data - TRAIN (1).csv")

# %%
target_test=pd.read_csv(r"C:\Users\ggomare\Downloads\Portugese Bank Data - TEST.csv")

# %%
target_test
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
target_train.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
len(target_train.columns)
# Out:
# 17

# %%
target_train.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
result_column=target_train.columns.drop(["age","balance","day","duration","campaign","pdays","previous"])

# %%
result_column
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
for i in result_column:
    target_train[i+"1"]=lb_encode.fit_transform(target_train[i])

# %%
target_train
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
final_target_train=target_train.drop(columns=result_column)

# %%
final_target_train
# Out:
#       age  balance  day  duration  campaign  pdays  previous  job1  marital1  \
# 0      30     1787   19        79         1     -1         0    10         1
# 1      33     4789   11       220         1    339         4     7         1
# 2      35     1350   16       185         1    330         1     4         2
# 3      30     1476    3       199         4     -1         0     4         1
# 4      59        0    5       226         1     -1         0     1         1
# ...   ...      ...  ...       ...       ...    ...       ...   ...       ...
# 4516   33     -333   30       329         5     -1         0     7         1
# 4517   57    -3313    9       153         1     -1         0     6         1
# 4518   57      295   19       151        11     -1         0     9         1
# 4519   28     1137    6       129         4    211         3     1         1
# 4520   44     1136    3       345         2    249         7     2         2
#
# ...

# %%
for i in result_column:
    target_test[i+"1"]=lb_encode.fit_transform(target_test[i])

# %%
target_test
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
final_target_test=target_train.drop(columns=result_column)

# %%
final_target_test
# Out:
#       age  balance  day  duration  campaign  pdays  previous  job1  marital1  \
# 0      30     1787   19        79         1     -1         0    10         1
# 1      33     4789   11       220         1    339         4     7         1
# 2      35     1350   16       185         1    330         1     4         2
# 3      30     1476    3       199         4     -1         0     4         1
# 4      59        0    5       226         1     -1         0     1         1
# ...   ...      ...  ...       ...       ...    ...       ...   ...       ...
# 4516   33     -333   30       329         5     -1         0     7         1
# 4517   57    -3313    9       153         1     -1         0     6         1
# 4518   57      295   19       151        11     -1         0     9         1
# 4519   28     1137    6       129         4    211         3     1         1
# 4520   44     1136    3       345         2    249         7     2         2
#
# ...

# %%
final_target_trainX=final_target_train.drop(columns=['y1'])

# %%
final_target_trainY=final_target_train["y1"]

# %%
final_target_testX=final_target_test.drop(columns=['y1'])

# %%
final_target_testY=final_target_test["y1"]

# %% [markdown]
# # Target Marketing Using DecisionTreeClassifier

# %% [markdown]
# Cross-validation for target marketing

# %%
#for train data
accuracy_Decision1=cross_val_score(tree.DecisionTreeClassifier(),final_target_trainX,final_target_trainY,cv=6)

# %%
sum(accuracy_Decision1)/len(accuracy_Decision1)
# Out:
# 0.8615352911959588

# %%
#for test data
accuracy_Decision2=cross_val_score(tree.DecisionTreeClassifier(),final_target_testX,final_target_testY,cv=6)

# %%
sum(accuracy_Decision2)/len(accuracy_Decision2)
# Out:
# 0.861316596273321

# %%
#Using GridSearchCV HyperparametrTunning
ModelM=GridSearchCV(DecisionTreeClassifier(),{
    "criterion":["gini", "entropy", "log_loss"],
    "splitter":["best", "random"], 
    "max_depth":[1,2,5,10,15],
     "min_samples_leaf":[1,2,4,8,10]
    },cv=6,return_train_score=False)
ModelM.fit(final_target_trainX,final_target_trainY)
# Out:
# GridSearchCV(cv=6, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4, 8, 10],
#                          'splitter': ['best', 'random']})

# %%
ModelM.best_score_
# Out:
# 0.8960403596342599

# %%
ModelM.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'min_samples_leaf': 2,
#  'splitter': 'best'}

# %%
gre4=DecisionTreeClassifier(criterion='gini',
 max_depth= 5,
 min_samples_leaf=2,
 splitter='best')
gre4.fit(final_target_trainX,final_target_trainY)
gre4.score(final_target_testX,final_target_testY)
pre4=gre4.predict(final_target_testX)

# %%
ModelM.fit(final_target_testX,final_target_testY)
# Out:
# GridSearchCV(cv=6, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4, 8, 10],
#                          'splitter': ['best', 'random']})

# %%
ModelM.best_score_
# Out:
# 0.8951623508911598

# %%
#Using RandomSearch

# %%
ModelR=RandomizedSearchCV(DecisionTreeClassifier(),{
    "criterion":["gini", "entropy", "log_loss"],
    "splitter":["best", "random"], 
    "max_depth":[1,2,5,10,15],
     "min_samples_leaf":[1,2,4,8,10]
    },cv=6,return_train_score=False)
ModelR.fit(final_target_trainX,final_target_trainY)
# Out:
# RandomizedSearchCV(cv=6, estimator=DecisionTreeClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': [1, 2, 5, 10, 15],
#                                         'min_samples_leaf': [1, 2, 4, 8, 10],
#                                         'splitter': ['best', 'random']})

# %%
ModelR.best_score_
# Out:
# 0.8944956983149043

# %%
#for test data of marketing
ModelR.fit(final_target_testX,final_target_testY)
# Out:
# RandomizedSearchCV(cv=6, estimator=DecisionTreeClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': [1, 2, 5, 10, 15],
#                                         'min_samples_leaf': [1, 2, 4, 8, 10],
#                                         'splitter': ['best', 'random']})

# %%
ModelR.best_score_
# Out:
# 0.8929516240960121

# %%
ModelR.best_params_
# Out:
# {'splitter': 'best',
#  'min_samples_leaf': 8,
#  'max_depth': 10,
#  'criterion': 'gini'}

# %%
gre5=DecisionTreeClassifier(splitter= 'best',
 min_samples_leaf= 8,
 max_depth= 10,
 criterion='gini')

# %%
gre5.fit(final_target_trainX,final_target_trainY)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=8)

# %%
pre5=gre5.predict(final_target_testX)

# %%
gre5.score(final_target_testX,final_target_testY)
# Out:
# 0.9318734793187348

# %%
print(classification_report(pre5,final_target_testY))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96      4156
#            1       0.55      0.79      0.65       365
#
#     accuracy                           0.93      4521
#    macro avg       0.77      0.87      0.81      4521
# weighted avg       0.95      0.93      0.94      4521

# %% [markdown]
# # Target Marketing using RandomForestClassifier()

# %%
#cross_validation using RandomForestClassifier()

# %%
#cross validation for train data
accuracy_DecisionR=cross_val_score(RandomForestClassifier(),final_target_trainX,final_target_trainY,cv=6)

# %%
sum(accuracy_DecisionR)/len(accuracy_DecisionR)
# Out:
# 0.896041240284955

# %%
#cross validation for test data
accuracy_DecisionR1=cross_val_score(RandomForestClassifier(),final_target_trainX,final_target_trainY,cv=6)

# %%
sum(accuracy_DecisionR1)/len(accuracy_DecisionR1)
# Out:
# 0.8944924692623553

# %%
rfc1=RandomForestClassifier(random_state=42)

# %%
param_grid = { 

     'max_features': ['sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
#Using GridsearchCV
ModelT= GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)

# %%
ModelT.fit(final_target_trainX,final_target_trainY)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['sqrt', 'log2']})

# %%
ModelT.best_score_
# Out:
# 0.8958194396909989

# %%
ModelT.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt'}

# %%
#for test Data
ModelT.fit(final_target_testX,final_target_testY)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['sqrt', 'log2']})

# %%
ModelT.best_score_
# Out:
# 0.8958194396909989

# %%
gre6=RandomForestClassifier(criterion='gini', max_depth=8, max_features='sqrt')

# %%
gre6.fit(final_target_trainX,final_target_trainY)
# Out:
# RandomForestClassifier(max_depth=8)

# %%
gre6.score(final_target_testX,final_target_testY)
# Out:
# 0.9420482194204822

# %%
pre6=gre6.predict(final_target_testX)

# %%
print(classification_report(final_target_testY,pre6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4000
#            1       0.99      0.50      0.67       521
#
#     accuracy                           0.94      4521
#    macro avg       0.96      0.75      0.82      4521
# weighted avg       0.94      0.94      0.93      4521

# %%
#Random search for target marketing

# %%
ModelTR= RandomizedSearchCV(estimator=rfc,param_distributions=param_grid ,cv= 5)

# %%
ModelTR.fit(final_target_trainX,final_target_trainY)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [4, 5, 6, 7, 8],
#                                         'max_features': ['sqrt', 'log2']})

# %%
ModelTR.best_score_
# Out:
# 0.8958194396909989

# %%
ModelTR.best_params_
# Out:
# {'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'gini'}

# %%
ModelTR.fit(final_target_testX,final_target_testY)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [4, 5, 6, 7, 8],
#                                         'max_features': ['sqrt', 'log2']})

# %%
ModelTR.best_score_
# Out:
# 0.8958194396909989

# %%
get7=RandomForestClassifier(max_features= 'sqrt', max_depth= 8, criterion= 'gini')

# %%
get7.fit(final_target_trainX,final_target_trainY)
# Out:
# RandomForestClassifier(max_depth=8)

# %%
pre7=get7.predict(final_target_testX)

# %%
get7.score(final_target_testX,final_target_testY)
# Out:
# 0.9433753594337536

# %%
print(classification_report(pre7,final_target_testY))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97      4244
#            1       0.52      0.98      0.68       277
#
#     accuracy                           0.94      4521
#    macro avg       0.76      0.96      0.82      4521
# weighted avg       0.97      0.94      0.95      4521
