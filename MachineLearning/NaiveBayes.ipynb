# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_digits

# %%
digits=load_digits()

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.target.shape
# Out:
# (1797,)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(digits.data,digits.target,test_size=0.28)

# %%
xtrain.shape
# Out:
# (1293, 64)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model1=GaussianNB()

# %%
model1.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
model1.score(xtest,ytest)
# Out:
# 0.8412698412698413

# %%
titan=pd.read_csv(r"C:\Users\ggomare\Downloads\titanic\train.csv")

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titan1=titan.drop(columns=["PassengerId","Survived","Name","Ticket"])

# %%
titan1
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         3    male  22.0      1      0   7.2500   NaN        S
# 1         1  female  38.0      1      0  71.2833   C85        C
# 2         3  female  26.0      0      0   7.9250   NaN        S
# 3         1  female  35.0      1      0  53.1000  C123        S
# 4         3    male  35.0      0      0   8.0500   NaN        S
# ..      ...     ...   ...    ...    ...      ...   ...      ...
# 886       2    male  27.0      0      0  13.0000   NaN        S
# 887       1  female  19.0      0      0  30.0000   B42        S
# 888       3  female   NaN      1      2  23.4500   NaN        S
# 889       1    male  26.0      0      0  30.0000  C148        C
# 890       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
titan1.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
titan1.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titan2=titan1.copy()

# %%
titan2.Sex.replace({
    'male':0,
    'female':1
}, inplace=True)

# %%
from collections import Counter

# %%
titan2
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         3    0  22.0      1      0   7.2500   NaN        S
# 1         1    1  38.0      1      0  71.2833   C85        C
# 2         3    1  26.0      0      0   7.9250   NaN        S
# 3         1    1  35.0      1      0  53.1000  C123        S
# 4         3    0  35.0      0      0   8.0500   NaN        S
# ..      ...  ...   ...    ...    ...      ...   ...      ...
# 886       2    0  27.0      0      0  13.0000   NaN        S
# 887       1    1  19.0      0      0  30.0000   B42        S
# 888       3    1   NaN      1      2  23.4500   NaN        S
# 889       1    0  26.0      0      0  30.0000  C148        C
# 890       3    0  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
Counter(titan2["Embarked"])
# Out:
# Counter({'S': 644, 'C': 168, 'Q': 77, nan: 2})

# %%
titan2.Embarked.replace({
    'S':1,
    'C':2,
    'Q':3
},inplace=True)

# %%
titan2
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare Cabin  Embarked
# 0         3    0  22.0      1      0   7.2500   NaN       1.0
# 1         1    1  38.0      1      0  71.2833   C85       2.0
# 2         3    1  26.0      0      0   7.9250   NaN       1.0
# 3         1    1  35.0      1      0  53.1000  C123       1.0
# 4         3    0  35.0      0      0   8.0500   NaN       1.0
# ..      ...  ...   ...    ...    ...      ...   ...       ...
# 886       2    0  27.0      0      0  13.0000   NaN       1.0
# 887       1    1  19.0      0      0  30.0000   B42       1.0
# 888       3    1   NaN      1      2  23.4500   NaN       1.0
# 889       1    0  26.0      0      0  30.0000  C148       2.0
# 890       3    0  32.0      0      0   7.7500   NaN       3.0
#
# [891 rows x 8 columns]

# %%
titan2["Embarked"]=titan2["Embarked"].fillna('Q')

# %%
titan2["Embarked"].isnull().sum()
# Out:
# 0

# %%
titan2.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      0
# dtype: int64

# %%
titan3=titan2.drop(columns=["Cabin"])

# %%
titan3
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0         3    0  22.0      1      0   7.2500      1.0
# 1         1    1  38.0      1      0  71.2833      2.0
# 2         3    1  26.0      0      0   7.9250      1.0
# 3         1    1  35.0      1      0  53.1000      1.0
# 4         3    0  35.0      0      0   8.0500      1.0
# ..      ...  ...   ...    ...    ...      ...      ...
# 886       2    0  27.0      0      0  13.0000      1.0
# 887       1    1  19.0      0      0  30.0000      1.0
# 888       3    1   NaN      1      2  23.4500      1.0
# 889       1    0  26.0      0      0  30.0000      2.0
# 890       3    0  32.0      0      0   7.7500      3.0
#
# [891 rows x 7 columns]

# %%
target=titan["Survived"]

# %%
target.shape
# Out:
# (891,)

# %%
titan3["Age"]=titan["Age"].fillna(titan3["Age"].mean())

# %%
titan3.Embarked.replace({
    'S':1,
    'C':2,
    'Q':3
},inplace=True)

# %%
titan3.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
titan3
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    0  22.000000      1      0   7.2500       1.0
# 1         1    1  38.000000      1      0  71.2833       2.0
# 2         3    1  26.000000      0      0   7.9250       1.0
# 3         1    1  35.000000      1      0  53.1000       1.0
# 4         3    0  35.000000      0      0   8.0500       1.0
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    0  27.000000      0      0  13.0000       1.0
# 887       1    1  19.000000      0      0  30.0000       1.0
# 888       3    1  29.699118      1      2  23.4500       1.0
# 889       1    0  26.000000      0      0  30.0000       2.0
# 890       3    0  32.000000      0      0   7.7500       3.0
#
# [891 rows x 7 columns]

# %%
titan3.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642    0.352413   29.699118    0.523008    0.381594   32.204208
# std      0.836071    0.477990   13.002015    1.102743    0.806057   49.693429
# min      1.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   22.000000    0.000000    0.000000    7.910400
# 50%      3.000000    0.000000   29.699118    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000    1.000000   80.000000    8.000000    6.000000  512.329200
#
#          Embarked
# count  891.000000
# mean     1.365881
# std      0.640157
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(titan3,target)

# %%
xtrain
# Out:
#      Pclass  Sex        Age  SibSp  Parch      Fare  Embarked
# 210       3    0  24.000000      0      0    7.0500       1.0
# 311       1    1  18.000000      2      2  262.3750       2.0
# 688       3    0  18.000000      0      0    7.7958       1.0
# 731       3    0  11.000000      0      0   18.7875       2.0
# 189       3    0  36.000000      0      0    7.8958       1.0
# ..      ...  ...        ...    ...    ...       ...       ...
# 745       1    0  70.000000      1      1   71.0000       1.0
# 551       2    0  27.000000      0      0   26.0000       1.0
# 295       1    0  29.699118      0      0   27.7208       2.0
# 364       3    0  29.699118      1      0   15.5000       3.0
# 190       2    1  32.000000      0      0   13.0000       1.0
#
# [668 rows x 7 columns]

# %%
model1=GaussianNB()

# %%
model1.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
model1.score(xtest,ytest)
# Out:
# 0.8071748878923767

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()
model2.fit(xtrain,ytrain)
model2.score(xtest,ytest)
# Out:
# 0.7802690582959642

# %%
from sklearn.ensemble import RandomForestClassifier
model3=RandomForestClassifier()
model3.fit(xtrain,ytrain)
model3.score(xtest,ytest)
# Out:
# 0.8430493273542601

# %%
from sklearn.ensemble import BaggingClassifier
model4=BaggingClassifier(base_estimator=RandomForestClassifier(),
    n_estimators=100,
    max_samples=0.8,
    oob_score=True,
    random_state=0)
model4.fit(xtrain,ytrain)
model4.score(xtest,ytest)
# Out:
# 0.8475336322869955

# %%
from sklearn.linear_model import LogisticRegression

# %%
model5=LogisticRegression()

# %%
import warnings
warnings.filterwarnings("ignore")
model5.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model5.score(xtest,ytest)
# Out:
# 0.8071748878923767

# %%
model6=BaggingClassifier(base_estimator=LogisticRegression(),
    n_estimators=100,
    max_samples=0.8,
    oob_score=True,
    random_state=0)
model6.fit(xtrain,ytrain)
model6.score(xtest,ytest)
# Out:
# 0.8071748878923767

# %%
test=pd.read_csv(r"C:\Users\ggomare\Downloads\titanic\test.csv")

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test.Sex.replace({
    'male':0,
    'female':1
},inplace=True)
test.Embarked.replace({
    'S':1,
    'C':2,
    'Q':3
},inplace=True)

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
# ...

# %%
test1=test.drop(columns=["PassengerId","Name","Ticket","Cabin"])

# %%
test1
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0         3    0  34.5      0      0    7.8292         3
# 1         3    1  47.0      1      0    7.0000         1
# 2         2    0  62.0      0      0    9.6875         3
# 3         3    0  27.0      0      0    8.6625         1
# 4         3    1  22.0      1      1   12.2875         1
# ..      ...  ...   ...    ...    ...       ...       ...
# 413       3    0   NaN      0      0    8.0500         1
# 414       1    1  39.0      0      0  108.9000         2
# 415       3    0  38.5      0      0    7.2500         1
# 416       3    0   NaN      0      0    8.0500         1
# 417       3    0   NaN      1      1   22.3583         2
#
# [418 rows x 7 columns]

# %%
test1.isnull().sum()
# Out:
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
test1["Age"]=test1["Age"].fillna(test1.Age.mean())

# %%
test1.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        1
# Embarked    0
# dtype: int64

# %%
test1.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000  417.000000
# mean     2.265550    0.363636   30.272590    0.447368    0.392344   35.627188
# std      0.841838    0.481622   12.634534    0.896760    0.981429   55.907576
# min      1.000000    0.000000    0.170000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000   23.000000    0.000000    0.000000    7.895800
# 50%      3.000000    0.000000   30.272590    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000   35.750000    1.000000    0.000000   31.500000
# max      3.000000    1.000000   76.000000    8.000000    9.000000  512.329200
#
#          Embarked
# count  418.000000
# mean     1.464115
# std      0.685516
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
test1["Fare"]=test1["Fare"].fillna(35.627188)

# %%
test1.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
pred=model3.predict(test1)

# %%
id=test["PassengerId"]

# %%
final=pd.DataFrame(pred,columns=["Survived"])

# %%
result=pd.concat([id,final],axis=1)

# %%
result.to_csv("Submission.csv",index=False)
