# %%
import pandas as pd
import numpy as np

# %%
food_data=pd.read_csv(r"C:\Users\ggomare\Downloads\reviews.csv")

# %%
food_data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
food_data.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
food_data.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# %%
import warnings
warnings.filterwarnings("ignore")

nltk.download('vader_lexicon')
sia=SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ggomare\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
res={}
for i,row in tqdm(food_data.iterrows(), total=len(food_data)):
    text=row["Text"]
    myid=row["Id"]
    res[myid]=sia.polarity_scores(text)
# Out:
#   0%|          | 0/568454 [00:00<?, ?it/s]

# %%
dataset = pd.DataFrame(res).T
dataset = dataset.reset_index().rename(columns={'index': 'Id'})
dataset = dataset.merge(food_data, how='left')

# %%
dataset
# Out:
#             Id    neg    neu    pos  compound   ProductId          UserId  \
# 0            1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1            2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2            3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3            4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4            5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
# ...        ...    ...    ...    ...       ...         ...             ...
# 568449  568450  0.072  0.600  0.327    0.8589  B001EO7N10  A28KG5XORO54AY
# 568450  568451  0.190  0.697  0.114   -0.4848  B003S1WTCU  A3I8AFVPEE8KI5
# 568451  568452  0.037  0.884  0.078    0.4352  B004I613EE  A121AA1GQV751Z
# 568452  568453  0.041  0.506  0.452    0.9717  B004I613EE   A3IBEVCTXKNOH
# 568453  568454  0.000  0.846  0.154    0.4754  B001LR2CU2  A3LGQPJCZVL9UC
#
#                             ProfileName  HelpfulnessNumerator  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax=sns.barplot(data=dataset, x='Score',y='compound')
ax.set_title('Compound Score by Amazon Star Review')
plt.show()

# %%
fig,axs=plt.subplots(1,3, figsize=(12,3))
sns.barplot(data=dataset ,x='Score',y='pos',ax=axs[0])
sns.barplot(data=dataset ,x='Score',y='neu',ax=axs[1])
sns.barplot(data=dataset ,x='Score',y='neg',ax=axs[2])
axs[0].set_title('positive')
axs[1].set_title('neutral')
axs[2].set_title('negative')
plt.show()
plt.tight_layout()

# %%
plt.tight_layout()

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
